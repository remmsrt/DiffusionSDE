# %% [markdown]
# # Score-Based Diffusion Model through SDEs from scratch

# %% [markdown]
# **Author:** SURAT Rémi

# %% [markdown]
# # I. Import MNIST dataset

# %%
import torch
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import torch
#       2 import torchvision
#
# ModuleNotFoundError: No module named 'torch'
